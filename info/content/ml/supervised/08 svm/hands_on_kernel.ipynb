# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.DataFrame(data=[
    [1, 1, 0], [1, 2, 0], [-1, 1, 0], [-1, -1, 0], [2, -2, 0], [1, -1, 0],
    [0.5, 0.5, 0], [0.8, 1, 0], [-0.5, 1, 0], [-1.2, -1.1, 0], [1.8, -0.5, 0], [1.4, -1.8, 0],
    [4, 5, 1], [-4, -3, 1], [5, -6, 1], [1, -7, 1], [2, 5, 1], [-1, 5, 1],
    [1, 5, 1], [-5, -2, 1], [2, -6, 1], [1, -7, 1], [-3, 4, 1], [-3, -5, 1],
], columns=['x', 'y', 'label'])

plt.figure(figsize=(3, 3))
sns.scatterplot(data=df, x='x', y='y', hue='label')
plt.axhline(y=0)
plt.axvline(x=0)
plt.show()

# %%
# kernel transformation
df['z'] = df['x'] ** 2 + df['y'] ** 2
df.head()
# Out:
#      x    y  label    z
# 0  1.0  1.0      0  2.0
# 1  1.0  2.0      0  5.0
# 2 -1.0  1.0      0  2.0
# 3 -1.0 -1.0      0  2.0
# 4  2.0 -2.0      0  8.0

# %%
plt.figure(figsize=(3, 3))
sns.scatterplot(data=df, x='x', y='z', hue='label')
plt.axhline(y=0)
plt.axvline(x=0)
plt.show()

# %%
plt.figure(figsize=(3, 3))
sns.scatterplot(data=df, x='y', y='z', hue='label')
plt.axhline(y=0)
plt.axvline(x=0)
plt.show()
